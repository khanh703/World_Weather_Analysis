# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# Import the requests library
import requests
from citipy import citipy

# Import the API key.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
sizecount = 2000
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=sizecount)
lngs = np.random.uniform(low=-180.000, high=180.000, size=sizecount)
# output is a zip object in memory
# zip object packs each pair of lats and lngs having the same index in their respective array into a tuple
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f" Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_description = city_weather["weather"][0]["description"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Date": city_date,
            "Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
    pass

    # Indicate that Data Loading is complete.
    print("-----------------------------")
    print("Data Retrieval Complete      ")
    print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
#  Processing Record 1 of Set 1 | dikson
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 2 of Set 1 | punta arenas
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 3 of Set 1 | hambantota
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 4 of Set 1 | ixtapa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 5 of Set 1 | san carlos de bariloche
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 6 of Set 1 | pevek
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 7 of Set 1 | busselton
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 8 of Set 1 | vaini
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 9 of Set 1 | kodiak
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 10 of Set 1 | saskylakh
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 11 of Set 1 | maningrida
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 12 of Set 1 | new norfolk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 13 of Set 1 | taguatinga
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 14 of Set 1 | celestun
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 15 of Set 1 | hilo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 16 of Set 1 | nanakuli
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 17 of Set 1 | mataura
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 18 of Set 1 | anloga
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 19 of Set 1 | raudeberg
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 20 of Set 1 | barrow
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 22 of Set 1 | zhangjiakou
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 23 of Set 1 | ilulissat
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 24 of Set 1 | hithadhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 25 of Set 1 | bambous virieux
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 26 of Set 1 | castro
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 27 of Set 1 | rikitea
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 28 of Set 1 | lithakia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 29 of Set 1 | inongo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 30 of Set 1 | albany
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 31 of Set 1 | umarkot
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 32 of Set 1 | chuy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 33 of Set 1 | boa vista
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 34 of Set 1 | veraval
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 35 of Set 1 | palu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 36 of Set 1 | bluff
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 37 of Set 1 | kahului
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 38 of Set 1 | tigil
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 39 of Set 1 | yellowknife
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 40 of Set 1 | matadi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 41 of Set 1 | mar del plata
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 42 of Set 1 | tuktoyaktuk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 43 of Set 1 | bilibino
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 44 of Set 1 | lebu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 45 of Set 1 | port augusta
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 46 of Set 1 | enumclaw
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 47 of Set 1 | ushuaia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 48 of Set 1 | port hardy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 49 of Set 1 | tasiilaq
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 50 of Set 1 | taybad
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 1 of Set 2 | brigantine
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 2 of Set 2 | souillac
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 3 of Set 2 | cape town
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 4 of Set 2 | yarmouth
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 5 of Set 2 | codrington
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 6 of Set 2 | vestmannaeyjar
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 7 of Set 2 | olafsvik
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 8 of Set 2 | hildburghausen
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 9 of Set 2 | fort nelson
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 10 of Set 2 | port blair
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 11 of Set 2 | kaitangata
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 12 of Set 2 | georgetown
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 13 of Set 2 | coquimbo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 14 of Set 2 | taolanaro
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 15 of Set 2 | puerto ayora
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 16 of Set 2 | jamestown
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 17 of Set 2 | san patricio
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 18 of Set 2 | egvekinot
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 19 of Set 2 | jardim
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 20 of Set 2 | manavalakurichi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 21 of Set 2 | palabuhanratu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 22 of Set 2 | belle fourche
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 23 of Set 2 | enshi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 24 of Set 2 | hobart
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 25 of Set 2 | kasongo-lunda
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 26 of Set 2 | amderma
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 27 of Set 2 | tumannyy
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 28 of Set 2 | zhuozhou
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 29 of Set 2 | esperance
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 30 of Set 2 | nizhneyansk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 31 of Set 2 | lewiston
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 32 of Set 2 | samarai
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 33 of Set 2 | port elizabeth
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 34 of Set 2 | qaanaaq
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 35 of Set 2 | faanui
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 36 of Set 2 | wum
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 37 of Set 2 | bras-panon
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 38 of Set 2 | maragogi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 39 of Set 2 | katra
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 40 of Set 2 | kingsport
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 41 of Set 2 | ponta do sol
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 42 of Set 2 | saleaula
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 43 of Set 2 | saint-ambroise
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 44 of Set 2 | carmo do paranaiba
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 45 of Set 2 | tuatapere
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 46 of Set 2 | port macquarie
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 47 of Set 2 | nicoya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 48 of Set 2 | mahebourg
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 49 of Set 2 | tsihombe
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 50 of Set 2 | pisco
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 1 of Set 3 | arraial do cabo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 2 of Set 3 | sobolevo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 3 of Set 3 | pangkalanbuun
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 4 of Set 3 | okha
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 5 of Set 3 | laguna
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 6 of Set 3 | campbell river
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 7 of Set 3 | airai
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 8 of Set 3 | sola
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 9 of Set 3 | ribeira grande
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 10 of Set 3 | saint-philippe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 11 of Set 3 | port alfred
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 12 of Set 3 | caravelas
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 13 of Set 3 | tezu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 14 of Set 3 | guozhen
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 15 of Set 3 | iqaluit
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 16 of Set 3 | belushya guba
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 17 of Set 3 | acari
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 18 of Set 3 | ilhabela
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 19 of Set 3 | padang
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 20 of Set 3 | attawapiskat
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 21 of Set 3 | dengfeng
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 22 of Set 3 | flinders
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 23 of Set 3 | natal
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 24 of Set 3 | belmonte
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 25 of Set 3 | shieli
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 26 of Set 3 | cherdyn
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 27 of Set 3 | ca mau
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 28 of Set 3 | isangel
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 29 of Set 3 | saint george
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 30 of Set 3 | beloha
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 31 of Set 3 | kavieng
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 32 of Set 3 | sao filipe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 33 of Set 3 | estelle
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 34 of Set 3 | chokurdakh
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 35 of Set 3 | prince rupert
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 36 of Set 3 | nikolskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 37 of Set 3 | barawe
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 38 of Set 3 | berasia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 39 of Set 3 | bethel
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 40 of Set 3 | amargosa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 41 of Set 3 | east london
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 42 of Set 3 | torbay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 43 of Set 3 | varzea da palma
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 44 of Set 3 | bengkulu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 45 of Set 3 | moron
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 46 of Set 3 | cherskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 47 of Set 3 | svetlogorsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 48 of Set 3 | howard springs
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 49 of Set 3 | hermanus
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 50 of Set 3 | labuhan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 1 of Set 4 | bolungarvik
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 2 of Set 4 | grand river south east
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 3 of Set 4 | avarua
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 4 of Set 4 | saint anthony
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 5 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 6 of Set 4 | cidreira
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 7 of Set 4 | pangnirtung
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 8 of Set 4 | chernyshevskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 9 of Set 4 | te anau
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 10 of Set 4 | carnarvon
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 11 of Set 4 | bredasdorp
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 12 of Set 4 | mys shmidta
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 13 of Set 4 | kapaa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 14 of Set 4 | nortelandia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 15 of Set 4 | ancud
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 16 of Set 4 | rio grande
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 17 of Set 4 | visnes
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 18 of Set 4 | goderich
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 19 of Set 4 | pierre
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 20 of Set 4 | den helder
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 21 of Set 4 | alyangula
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 22 of Set 4 | verkhoyansk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 23 of Set 4 | yaan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 24 of Set 4 | strelka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 25 of Set 4 | mogadishu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 26 of Set 4 | alugan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 27 of Set 4 | lere
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 28 of Set 4 | victoria
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 29 of Set 4 | fort saint john
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 30 of Set 4 | parabel
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 31 of Set 4 | coihaique
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 32 of Set 4 | macau
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 33 of Set 4 | provideniya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 34 of Set 4 | kanker
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 35 of Set 4 | los llanos de aridane
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 36 of Set 4 | aguimes
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 37 of Set 4 | kimbe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 38 of Set 4 | hofn
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 39 of Set 4 | calatayud
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 40 of Set 4 | nemuro
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 41 of Set 4 | harboore
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 42 of Set 4 | buraydah
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 43 of Set 4 | fiumicino
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 44 of Set 4 | namibe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 45 of Set 4 | zomba
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 46 of Set 4 | severo-kurilsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 47 of Set 4 | terra boa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 48 of Set 4 | fortuna
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 49 of Set 4 | san cristobal
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 50 of Set 4 | cabo san lucas
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 1 of Set 5 | biliran
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 2 of Set 5 | grindavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 3 of Set 5 | hasaki
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 4 of Set 5 | komsomolskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 5 of Set 5 | horsham
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 6 of Set 5 | baie-comeau
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 7 of Set 5 | dianopolis
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 8 of Set 5 | lagoa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 9 of Set 5 | longyearbyen
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 10 of Set 5 | soyaux
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 11 of Set 5 | ambon
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 12 of Set 5 | gombe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 13 of Set 5 | quatre cocos
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 14 of Set 5 | richards bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 15 of Set 5 | nyurba
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 16 of Set 5 | butaritari
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 17 of Set 5 | araouane
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 18 of Set 5 | atuona
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 19 of Set 5 | bud
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 20 of Set 5 | sitka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 21 of Set 5 | alihe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 22 of Set 5 | honningsvag
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 23 of Set 5 | salalah
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 24 of Set 5 | angouleme
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 25 of Set 5 | eutin
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 26 of Set 5 | acuna
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 27 of Set 5 | socorro
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 28 of Set 5 | beringovskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 29 of Set 5 | hinton
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 30 of Set 5 | pedra
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 31 of Set 5 | lorengau
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 32 of Set 5 | nacozari
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 33 of Set 5 | petropavlovsk-kamchatskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 34 of Set 5 | claveria
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 35 of Set 5 | bathsheba
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 36 of Set 5 | hamilton
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 37 of Set 5 | vastervik
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 38 of Set 5 | payson
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 39 of Set 5 | obo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 40 of Set 5 | terra nova
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 41 of Set 5 | praia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 42 of Set 5 | san andres
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 43 of Set 5 | thompson
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 44 of Set 5 | khatanga
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 45 of Set 5 | wuwei
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 46 of Set 5 | teya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 47 of Set 5 | ouargaye
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 48 of Set 5 | awjilah
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 49 of Set 5 | turukhansk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 50 of Set 5 | cagmanaba
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 1 of Set 6 | kosh-agach
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 2 of Set 6 | dingle
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 3 of Set 6 | katherine
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 4 of Set 6 | na wa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 5 of Set 6 | suclayin
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 6 of Set 6 | severo-yeniseyskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 7 of Set 6 | bantry
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 8 of Set 6 | katobu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 9 of Set 6 | mtambile
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 10 of Set 6 | najran
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 11 of Set 6 | czersk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 12 of Set 6 | marakkanam
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 13 of Set 6 | sao joao da barra
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 14 of Set 6 | norman wells
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 15 of Set 6 | upernavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 16 of Set 6 | broome
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 17 of Set 6 | kutum
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 18 of Set 6 | vangaindrano
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 19 of Set 6 | clyde river
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 20 of Set 6 | anuradhapura
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 21 of Set 6 | bandarbeyla
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 22 of Set 6 | comodoro rivadavia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 23 of Set 6 | makambako
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 24 of Set 6 | kupang
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 25 of Set 6 | norwich
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 26 of Set 6 | touros
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 27 of Set 6 | beyla
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 28 of Set 6 | menongue
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 29 of Set 6 | znamenka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 30 of Set 6 | rocha
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 31 of Set 6 | rongcheng
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 32 of Set 6 | manokwari
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 33 of Set 6 | itarema
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 34 of Set 6 | cumaribo
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 35 of Set 6 | srednekolymsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 36 of Set 6 | marcona
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 37 of Set 6 | saint-louis
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 38 of Set 6 | turgoyak
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 39 of Set 6 | ostrovnoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 40 of Set 6 | lucenec
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 41 of Set 6 | guerrero negro
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 42 of Set 6 | morgan city
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 43 of Set 6 | asfi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 44 of Set 6 | oistins
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 45 of Set 6 | tiksi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 46 of Set 6 | viedma
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 47 of Set 6 | lopatino
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 48 of Set 6 | marzuq
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 49 of Set 6 | malakal
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 50 of Set 6 | morehead
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 1 of Set 7 | pedasi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 2 of Set 7 | alice springs
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 3 of Set 7 | lundazi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 4 of Set 7 | lufilufi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 5 of Set 7 | almunecar
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 6 of Set 7 | toamasina
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 7 of Set 7 | linkou
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 8 of Set 7 | rottingdean
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 9 of Set 7 | serang
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 10 of Set 7 | tura
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 11 of Set 7 | talnakh
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 12 of Set 7 | samusu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 13 of Set 7 | sorvag
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 14 of Set 7 | oussouye
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 15 of Set 7 | datong
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 16 of Set 7 | stoyba
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 17 of Set 7 | paamiut
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 18 of Set 7 | constitucion
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 19 of Set 7 | qinhuangdao
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 20 of Set 7 | soyo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 21 of Set 7 | mercedes
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 22 of Set 7 | mangochi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 23 of Set 7 | road town
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 24 of Set 7 | ahar
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 25 of Set 7 | sept-iles
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 26 of Set 7 | athabasca
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 27 of Set 7 | kibondo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 28 of Set 7 | yekaterinovka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 29 of Set 7 | hami
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 30 of Set 7 | ballina
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 31 of Set 7 | namatanai
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 32 of Set 7 | buala
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 33 of Set 7 | mahon
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 34 of Set 7 | muscat
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 35 of Set 7 | araguacu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 36 of Set 7 | avera
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 37 of Set 7 | daniel flores
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 38 of Set 7 | praia da vitoria
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 39 of Set 7 | anderson
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 40 of Set 7 | vila franca do campo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 41 of Set 7 | berlevag
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 42 of Set 7 | shimoda
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 43 of Set 7 | katsuura
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 44 of Set 7 | garhakota
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 45 of Set 7 | vaitupu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 46 of Set 7 | koscian
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 47 of Set 7 | lolua
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 48 of Set 7 | toliary
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 49 of Set 7 | pouembout
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 50 of Set 7 | mehamn
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 1 of Set 8 | kandrian
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 2 of Set 8 | jinchengjiang
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 3 of Set 8 | hawick
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 4 of Set 8 | hendersonville
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 5 of Set 8 | mormugao
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 6 of Set 8 | esna
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# ...
# Data Retrieval Complete
# -----------------------------
#  Processing Record 36 of Set 13 | zangakatun
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 37 of Set 13 | grootfontein
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 38 of Set 13 | say
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 39 of Set 13 | baiyin
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 40 of Set 13 | onokhoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 41 of Set 13 | astana
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 42 of Set 13 | aljezur
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 43 of Set 13 | cagayan de tawi-tawi
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 44 of Set 13 | bilma
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 45 of Set 13 | shkotovo-26
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 46 of Set 13 | tiverton
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 47 of Set 13 | wajir
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 48 of Set 13 | middle island
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 49 of Set 13 | udachnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 50 of Set 13 | pak phanang
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 1 of Set 14 | gandorhun
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 2 of Set 14 | moba
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 3 of Set 14 | khandyga
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 4 of Set 14 | urumqi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 5 of Set 14 | mazatlan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 6 of Set 14 | marataizes
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 7 of Set 14 | broken hill
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 8 of Set 14 | chauk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 9 of Set 14 | maceio
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 10 of Set 14 | jining
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 11 of Set 14 | alofi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 12 of Set 14 | kawalu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 13 of Set 14 | ravar
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 14 of Set 14 | havoysund
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 15 of Set 14 | yantal
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 16 of Set 14 | zhmerynka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 17 of Set 14 | solano
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 18 of Set 14 | clinton
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 19 of Set 14 | mikuni
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 20 of Set 14 | westport
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 21 of Set 14 | kolyvan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 22 of Set 14 | khoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 23 of Set 14 | huarmey
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 24 of Set 14 | centralia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 25 of Set 14 | kaa-khem
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 26 of Set 14 | inirida
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 27 of Set 14 | kamyzyak
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 28 of Set 14 | doha
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 29 of Set 14 | kulhudhuffushi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 30 of Set 14 | biggar
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 31 of Set 14 | vilyuysk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 32 of Set 14 | el seibo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 33 of Set 14 | shelburne
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 34 of Set 14 | donskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 35 of Set 14 | mbini
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 36 of Set 14 | chaa-khol
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 37 of Set 14 | canakkale
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 38 of Set 14 | anadyr
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 39 of Set 14 | corn island
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 40 of Set 14 | zykovo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 41 of Set 14 | moroni
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 42 of Set 14 | queanbeyan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 43 of Set 14 | snezhnogorsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 44 of Set 14 | asau
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 45 of Set 14 | waipawa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 46 of Set 14 | halalo
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 47 of Set 14 | bolshiye uki
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 48 of Set 14 | solnechnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 49 of Set 14 | sarankhola
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 50 of Set 14 | north bend
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 1 of Set 15 | hobyo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 2 of Set 15 | cheyur
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 3 of Set 15 | ruatoria
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 4 of Set 15 | moscow
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 5 of Set 15 | vardo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 6 of Set 15 | ust-uda
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 7 of Set 15 | puerto palomas
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 8 of Set 15 | ust-barguzin
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 9 of Set 15 | ripoll
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 10 of Set 15 | abha
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 11 of Set 15 | iralaya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 12 of Set 15 | andros town
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 13 of Set 15 | shingu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 14 of Set 15 | vao
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 15 of Set 15 | almora
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 16 of Set 15 | daru
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 17 of Set 15 | wanaka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 18 of Set 15 | santa rosa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 19 of Set 15 | gari
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 20 of Set 15 | cam ranh
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 21 of Set 15 | mucurapo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 22 of Set 15 | viligili
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 23 of Set 15 | yerbogachen
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 24 of Set 15 | alto baudo
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 25 of Set 15 | tabiauea
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 26 of Set 15 | zhezkazgan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 27 of Set 15 | florence
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 28 of Set 15 | zheleznodorozhnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 29 of Set 15 | bikaner
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 30 of Set 15 | bani walid
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 31 of Set 15 | kudat
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 32 of Set 15 | cedar city
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 33 of Set 15 | ponta delgada
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 34 of Set 15 | neiafu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 35 of Set 15 | vacha
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 36 of Set 15 | huntingdon
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 37 of Set 15 | cache creek
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 38 of Set 15 | tebingtinggi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 39 of Set 15 | whitehorse
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 40 of Set 15 | priyutnoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 41 of Set 15 | riacho de santana
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 42 of Set 15 | yulara
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 43 of Set 15 | talcahuano
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 44 of Set 15 | shuyskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 45 of Set 15 | himora
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 46 of Set 15 | saryshagan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 47 of Set 15 | bereda
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 48 of Set 15 | kentau
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 49 of Set 15 | lushunkou
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 50 of Set 15 | banda aceh
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 1 of Set 16 | zhanatas
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#  Processing Record 2 of Set 16 | narsaq
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 6.93,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 16.26,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:07:25',
#   'Description': 'overcast clouds'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 53.11,
#   'Humidity': 40,
#   'Cloudiness': 59,
#   'Wind Speed': 7.45,
#   'Country': 'CL',
#   'Date': '2021-10-30 21:00:37',
#   'Description': 'broken clouds'},
#  {'City': 'Hambantota',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 78.51,
#   'Humidity': 84,
#   'Cloudiness': 79,
#   'Wind Speed': 3.11,
#   'Country': 'LK',
#   'Date': '2021-10-30 21:07:26',
#   'Description': 'broken clouds'},
#  {'City': 'Ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 85.23,
#   'Humidity': 81,
#   'Cloudiness': 43,
#   'Wind Speed': 5.99,
#   'Country': 'MX',
#   'Date': '2021-10-30 21:07:26',
#   'Description': 'scattered clouds'},
#  {'City': 'San Carlos De Bariloche',
#   'Lat': -41.1456,
#   'Lng': -71.3082,
#   'Max Temp': 62.35,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Country': 'AR',
#   'Date': '2021-10-30 21:04:19',
#   'Description': 'clear sky'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -3.24,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 10.49,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:07:27',
#   'Description': 'overcast clouds'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 43.05,
#   'Humidity': 90,
#   'Cloudiness': 92,
#   'Wind Speed': 5.73,
#   'Country': 'AU',
#   'Date': '2021-10-30 21:07:27',
#   'Description': 'overcast clouds'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 75.22,
#   'Humidity': 77,
#   'Cloudiness': 9,
#   'Wind Speed': 16.24,
#   'Country': 'TO',
#   'Date': '2021-10-30 21:07:00',
#   'Description': 'clear sky'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 47.71,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 34.52,
#   'Country': 'US',
#   'Date': '2021-10-30 21:04:51',
#   'Description': 'light rain'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 9.75,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 11.63,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:07:29',
#   'Description': 'overcast clouds'},
#  {'City': 'Maningrida',
#   'Lat': -12.0667,
#   'Lng': 134.2667,
#   'Max Temp': 79.93,
#   'Humidity': 76,
#   'Cloudiness': 97,
#   'Wind Speed': 4.74,
#   'Country': 'AU',
#   'Date': '2021-10-30 21:07:29',
#   'Description': 'overcast clouds'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 55.92,
#   'Humidity': 58,
#   'Cloudiness': 85,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Date': '2021-10-30 21:00:38',
#   'Description': 'overcast clouds'},
#  {'City': 'Taguatinga',
#   'Lat': -12.3857,
#   'Lng': -46.5711,
#   'Max Temp': 82.22,
#   'Humidity': 53,
#   'Cloudiness': 81,
#   'Wind Speed': 3.58,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:07:30',
#   'Description': 'broken clouds'},
#  {'City': 'Celestun',
#   'Lat': 20.8667,
#   'Lng': -90.4,
#   'Max Temp': 79.29,
#   'Humidity': 53,
#   'Cloudiness': 22,
#   'Wind Speed': 10.47,
#   'Country': 'MX',
#   'Date': '2021-10-30 21:07:30',
#   'Description': 'few clouds'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 80.33,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-10-30 21:07:31',
#   'Description': 'clear sky'},
#  {'City': 'Nanakuli',
#   'Lat': 21.3906,
#   'Lng': -158.1547,
#   'Max Temp': 85.37,
#   'Humidity': 51,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-10-30 21:07:31',
#   'Description': 'few clouds'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 57.43,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 12.01,
#   'Country': 'NZ',
#   'Date': '2021-10-30 21:00:27',
#   'Description': 'overcast clouds'},
#  {'City': 'Anloga',
#   'Lat': 5.7947,
#   'Lng': 0.8973,
#   'Max Temp': 81.79,
#   'Humidity': 80,
#   'Cloudiness': 59,
#   'Wind Speed': 11.9,
#   'Country': 'GH',
#   'Date': '2021-10-30 21:07:32',
#   'Description': 'broken clouds'},
#  {'City': 'Raudeberg',
#   'Lat': 61.9875,
#   'Lng': 5.1352,
#   'Max Temp': 51.87,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 10,
#   'Country': 'NO',
#   'Date': '2021-10-30 21:07:32',
#   'Description': 'light rain'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 17.62,
#   'Humidity': 79,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': '2021-10-30 21:00:32',
#   'Description': 'overcast clouds'},
#  {'City': 'Zhangjiakou',
#   'Lat': 40.81,
#   'Lng': 114.8794,
#   'Max Temp': 39.4,
#   'Humidity': 62,
#   'Cloudiness': 8,
#   'Wind Speed': 7.96,
#   'Country': 'CN',
#   'Date': '2021-10-30 21:07:33',
#   'Description': 'clear sky'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 37.42,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'GL',
#   'Date': '2021-10-30 21:07:33',
#   'Description': 'few clouds'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 83.08,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 19.35,
#   'Country': 'MV',
#   'Date': '2021-10-30 21:00:31',
#   'Description': 'light rain'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 70.21,
#   'Humidity': 77,
#   'Cloudiness': 32,
#   'Wind Speed': 6.06,
#   'Country': 'MU',
#   'Date': '2021-10-30 21:07:34',
#   'Description': 'scattered clouds'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 64.35,
#   'Humidity': 90,
#   'Cloudiness': 82,
#   'Wind Speed': 10.18,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:07:34',
#   'Description': 'broken clouds'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 75.02,
#   'Humidity': 85,
#   'Cloudiness': 73,
#   'Wind Speed': 21.88,
#   'Country': 'PF',
#   'Date': '2021-10-30 21:00:33',
#   'Description': 'light rain'},
#  {'City': 'Lithakia',
#   'Lat': 37.7167,
#   'Lng': 20.8333,
#   'Max Temp': 63.59,
#   'Humidity': 63,
#   'Cloudiness': 11,
#   'Wind Speed': 7.76,
#   'Country': 'GR',
#   'Date': '2021-10-30 21:07:35',
#   'Description': 'few clouds'},
#  {'City': 'Inongo',
#   'Lat': -1.95,
#   'Lng': 18.2667,
#   'Max Temp': 72.95,
#   'Humidity': 85,
#   'Cloudiness': 51,
#   'Wind Speed': 3.6,
#   'Country': 'CD',
#   'Date': '2021-10-30 21:07:35',
#   'Description': 'broken clouds'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 58.46,
#   'Humidity': 89,
#   'Cloudiness': 91,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2021-10-30 21:07:35',
#   'Description': 'overcast clouds'},
#  {'City': 'Umarkot',
#   'Lat': 25.3616,
#   'Lng': 69.7362,
#   'Max Temp': 76.42,
#   'Humidity': 23,
#   'Cloudiness': 7,
#   'Wind Speed': 7.23,
#   'Country': 'PK',
#   'Date': '2021-10-30 21:07:36',
#   'Description': 'clear sky'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 69.15,
#   'Humidity': 80,
#   'Cloudiness': 84,
#   'Wind Speed': 13.71,
#   'Country': 'UY',
#   'Date': '2021-10-30 21:07:36',
#   'Description': 'broken clouds'},
#  {'City': 'Boa Vista',
#   'Lat': 2.8197,
#   'Lng': -60.6733,
#   'Max Temp': 93.18,
#   'Humidity': 43,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:07:37',
#   'Description': 'scattered clouds'},
#  {'City': 'Veraval',
#   'Lat': 20.9,
#   'Lng': 70.3667,
#   'Max Temp': 76.41,
#   'Humidity': 44,
#   'Cloudiness': 93,
#   'Wind Speed': 9.69,
#   'Country': 'IN',
#   'Date': '2021-10-30 21:07:37',
#   'Description': 'overcast clouds'},
#  {'City': 'Palu',
#   'Lat': -0.8917,
#   'Lng': 119.8707,
#   'Max Temp': 74.61,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.04,
#   'Country': 'ID',
#   'Date': '2021-10-30 21:07:38',
#   'Description': 'overcast clouds'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 52.92,
#   'Humidity': 85,
#   'Cloudiness': 93,
#   'Wind Speed': 22.17,
#   'Country': 'NZ',
#   'Date': '2021-10-30 20:57:30',
#   'Description': 'light rain'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 85.26,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': '2021-10-30 21:07:06',
#   'Description': 'few clouds'},
#  {'City': 'Tigil',
#   'Lat': 57.8,
#   'Lng': 158.6667,
#   'Max Temp': 26.87,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.29,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:07:39',
#   'Description': 'light snow'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 30.56,
#   'Humidity': 85,
#   'Cloudiness': 95,
#   'Wind Speed': 8.01,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:07:39',
#   'Description': 'overcast clouds'},
#  {'City': 'Matadi',
#   'Lat': -5.8167,
#   'Lng': 13.45,
#   'Max Temp': 78.58,
#   'Humidity': 86,
#   'Cloudiness': 74,
#   'Wind Speed': 6.98,
#   'Country': 'CD',
#   'Date': '2021-10-30 21:07:40',
#   'Description': 'broken clouds'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 62.1,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Country': 'AR',
#   'Date': '2021-10-30 21:07:41',
#   'Description': 'broken clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 16.95,
#   'Humidity': 89,
#   'Cloudiness': 77,
#   'Wind Speed': 8.72,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:03:16',
#   'Description': 'broken clouds'},
#  {'City': 'Bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -9.42,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.57,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:07:41',
#   'Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 55.06,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 15.05,
#   'Country': 'CL',
#   'Date': '2021-10-30 21:07:42',
#   'Description': 'overcast clouds'},
#  {'City': 'Port Augusta',
#   'Lat': -32.5,
#   'Lng': 137.7667,
#   'Max Temp': 55.71,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 4.29,
#   'Country': 'AU',
#   'Date': '2021-10-30 21:07:42',
#   'Description': 'overcast clouds'},
#  {'City': 'Enumclaw',
#   'Lat': 47.2043,
#   'Lng': -121.9915,
#   'Max Temp': 54.81,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 3.58,
#   'Country': 'US',
#   'Date': '2021-10-30 21:07:43',
#   'Description': 'clear sky'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 55.06,
#   'Humidity': 41,
#   'Cloudiness': 13,
#   'Wind Speed': 3.87,
#   'Country': 'AR',
#   'Date': '2021-10-30 21:00:35',
#   'Description': 'few clouds'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 45.43,
#   'Humidity': 53,
#   'Cloudiness': 63,
#   'Wind Speed': 4.83,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:07:43',
#   'Description': 'broken clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 26.76,
#   'Humidity': 64,
#   'Cloudiness': 88,
#   'Wind Speed': 5.88,
#   'Country': 'GL',
#   'Date': '2021-10-30 21:03:12',
#   'Description': 'overcast clouds'},
#  {'City': 'Taybad',
#   'Lat': 34.74,
#   'Lng': 60.7756,
#   'Max Temp': 56.97,
#   'Humidity': 30,
#   'Cloudiness': 8,
#   'Wind Speed': 10.27,
#   'Country': 'IR',
#   'Date': '2021-10-30 21:07:44',
#   'Description': 'clear sky'},
#  {'City': 'Brigantine',
#   'Lat': 39.4101,
#   'Lng': -74.3646,
#   'Max Temp': 64.45,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-10-30 21:07:44',
#   'Description': 'scattered clouds'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 70.36,
#   'Humidity': 78,
#   'Cloudiness': 25,
#   'Wind Speed': 3.02,
#   'Country': 'MU',
#   'Date': '2021-10-30 21:07:45',
#   'Description': 'scattered clouds'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 63.09,
#   'Humidity': 77,
#   'Cloudiness': 71,
#   'Wind Speed': 1.01,
#   'Country': 'ZA',
#   'Date': '2021-10-30 21:03:22',
#   'Description': 'broken clouds'},
#  {'City': 'Yarmouth',
#   'Lat': 41.7057,
#   'Lng': -70.2286,
#   'Max Temp': 63.14,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 8.99,
#   'Country': 'US',
#   'Date': '2021-10-30 21:07:45',
#   'Description': 'overcast clouds'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 45.77,
#   'Humidity': 88,
#   'Cloudiness': 3,
#   'Wind Speed': 8.16,
#   'Country': 'AU',
#   'Date': '2021-10-30 21:07:46',
#   'Description': 'clear sky'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 43.57,
#   'Humidity': 77,
#   'Cloudiness': 83,
#   'Wind Speed': 5.46,
#   'Country': 'IS',
#   'Date': '2021-10-30 21:07:46',
#   'Description': 'broken clouds'},
#  {'City': 'Olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 43.29,
#   'Humidity': 90,
#   'Cloudiness': 73,
#   'Wind Speed': 20.49,
#   'Country': 'IS',
#   'Date': '2021-10-30 21:01:43',
#   'Description': 'broken clouds'},
#  {'City': 'Hildburghausen',
#   'Lat': 50.4255,
#   'Lng': 10.7318,
#   'Max Temp': 55.17,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 6.11,
#   'Country': 'DE',
#   'Date': '2021-10-30 21:07:47',
#   'Description': 'overcast clouds'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': 41.83,
#   'Humidity': 32,
#   'Cloudiness': 7,
#   'Wind Speed': 3.29,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:07:47',
#   'Description': 'clear sky'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 80.38,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 2.35,
#   'Country': 'IN',
#   'Date': '2021-10-30 21:07:47',
#   'Description': 'overcast clouds'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 58.05,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 5.86,
#   'Country': 'NZ',
#   'Date': '2021-10-30 21:07:48',
#   'Description': 'overcast clouds'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 77.9,
#   'Humidity': 92,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'MY',
#   'Date': '2021-10-30 21:07:48',
#   'Description': 'few clouds'},
#  {'City': 'Coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 60.53,
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'CL',
#   'Date': '2021-10-30 21:07:23',
#   'Description': 'few clouds'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 78.76,
#   'Humidity': 81,
#   'Cloudiness': 94,
#   'Wind Speed': 9.22,
#   'Country': 'EC',
#   'Date': '2021-10-30 21:07:49',
#   'Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 56.52,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2021-10-30 21:06:46',
#   'Description': 'overcast clouds'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 86.41,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 2.17,
#   'Country': 'US',
#   'Date': '2021-10-30 21:07:50',
#   'Description': 'clear sky'},
#  {'City': 'Egvekinot',
#   'Lat': 66.3167,
#   'Lng': -179.1667,
#   'Max Temp': 0.5,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 10.78,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:07:50',
#   'Description': 'overcast clouds'},
#  {'City': 'Jardim',
#   'Lat': -21.4803,
#   'Lng': -56.1381,
#   'Max Temp': 76.5,
#   'Humidity': 81,
#   'Cloudiness': 86,
#   'Wind Speed': 4.7,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:07:50',
#   'Description': 'overcast clouds'},
#  {'City': 'Manavalakurichi',
#   'Lat': 8.1333,
#   'Lng': 77.3,
#   'Max Temp': 78.89,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 4.41,
#   'Country': 'IN',
#   'Date': '2021-10-30 21:07:51',
#   'Description': 'overcast clouds'},
#  {'City': 'Belle Fourche',
#   'Lat': 44.6714,
#   'Lng': -103.8522,
#   'Max Temp': 46.51,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 14.2,
#   'Country': 'US',
#   'Date': '2021-10-30 21:07:51',
#   'Description': 'overcast clouds'},
#  {'City': 'Enshi',
#   'Lat': 30.3,
#   'Lng': 109.4833,
#   'Max Temp': 57.42,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 0.38,
#   'Country': 'CN',
#   'Date': '2021-10-30 21:07:52',
#   'Description': 'overcast clouds'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 56.26,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 4,
#   'Country': 'AU',
#   'Date': '2021-10-30 21:00:28',
#   'Description': 'broken clouds'},
#  {'City': 'Kasongo-Lunda',
#   'Lat': -6.4667,
#   'Lng': 16.8167,
#   'Max Temp': 70.97,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 0.74,
#   'Country': 'CD',
#   'Date': '2021-10-30 21:07:52',
#   'Description': 'overcast clouds'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 56.21,
#   'Humidity': 69,
#   'Cloudiness': 13,
#   'Wind Speed': 14.83,
#   'Country': 'AU',
#   'Date': '2021-10-30 21:07:53',
#   'Description': 'few clouds'},
#  {'City': 'Lewiston',
#   'Lat': 44.1003,
#   'Lng': -70.2148,
#   'Max Temp': 54.23,
#   'Humidity': 98,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2021-10-30 21:07:54',
#   'Description': 'mist'},
#  {'City': 'Samarai',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 82.72,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 13.67,
#   'Country': 'PG',
#   'Date': '2021-10-30 21:07:54',
#   'Description': 'overcast clouds'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 57.09,
#   'Humidity': 93,
#   'Cloudiness': 4,
#   'Wind Speed': 3.42,
#   'Country': 'ZA',
#   'Date': '2021-10-30 21:07:55',
#   'Description': 'clear sky'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 2.01,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 8.72,
#   'Country': 'GL',
#   'Date': '2021-10-30 21:07:55',
#   'Description': 'clear sky'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 78.13,
#   'Humidity': 69,
#   'Cloudiness': 15,
#   'Wind Speed': 16.46,
#   'Country': 'PF',
#   'Date': '2021-10-30 21:07:55',
#   'Description': 'few clouds'},
#  {'City': 'Wum',
#   'Lat': 6.3833,
#   'Lng': 10.0667,
#   'Max Temp': 65.23,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 2.62,
#   'Country': 'CM',
#   'Date': '2021-10-30 21:07:56',
#   'Description': 'light rain'},
#  {'City': 'Bras-Panon',
#   'Lat': -20.9967,
#   'Lng': 55.6782,
#   'Max Temp': 71.22,
#   'Humidity': 82,
#   'Cloudiness': 55,
#   'Wind Speed': 3.67,
#   'Country': 'RE',
#   'Date': '2021-10-30 21:07:56',
#   'Description': 'broken clouds'},
#  {'City': 'Maragogi',
#   'Lat': -9.0122,
#   'Lng': -35.2225,
#   'Max Temp': 77.02,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:07:57',
#   'Description': 'clear sky'},
#  {'City': 'Katra',
#   'Lat': 32.9833,
#   'Lng': 74.95,
#   'Max Temp': 55.71,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 9.01,
#   'Country': 'IN',
#   'Date': '2021-10-30 21:07:57',
#   'Description': 'clear sky'},
#  {'City': 'Kingsport',
#   'Lat': 36.5484,
#   'Lng': -82.5618,
#   'Max Temp': 55.26,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-10-30 21:04:53',
#   'Description': 'mist'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 72.72,
#   'Humidity': 76,
#   'Cloudiness': 31,
#   'Wind Speed': 6.96,
#   'Country': 'PT',
#   'Date': '2021-10-30 20:56:20',
#   'Description': 'scattered clouds'},
#  {'City': 'Saint-Ambroise',
#   'Lat': 48.5501,
#   'Lng': -71.3324,
#   'Max Temp': 49.59,
#   'Humidity': 61,
#   'Cloudiness': 82,
#   'Wind Speed': 9.64,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:07:58',
#   'Description': 'broken clouds'},
#  {'City': 'Carmo Do Paranaiba',
#   'Lat': -19.0008,
#   'Lng': -46.3161,
#   'Max Temp': 71.44,
#   'Humidity': 69,
#   'Cloudiness': 99,
#   'Wind Speed': 3.96,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:07:59',
#   'Description': 'overcast clouds'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 49.62,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 16.4,
#   'Country': 'NZ',
#   'Date': '2021-10-30 21:07:59',
#   'Description': 'overcast clouds'},
#  {'City': 'Port Macquarie',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 58.96,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 8.16,
#   'Country': 'AU',
#   'Date': '2021-10-30 21:08:00',
#   'Description': 'overcast clouds'},
#  {'City': 'Nicoya',
#   'Lat': 10.1483,
#   'Lng': -85.452,
#   'Max Temp': 76.55,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 2.42,
#   'Country': 'CR',
#   'Date': '2021-10-30 21:08:00',
#   'Description': 'overcast clouds'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 70.25,
#   'Humidity': 77,
#   'Cloudiness': 25,
#   'Wind Speed': 4.88,
#   'Country': 'MU',
#   'Date': '2021-10-30 21:08:01',
#   'Description': 'scattered clouds'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 66.25,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'PE',
#   'Date': '2021-10-30 21:08:01',
#   'Description': 'clear sky'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 73.26,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'BR',
#   'Date': '2021-10-30 20:58:23',
#   'Description': 'mist'},
#  {'City': 'Sobolevo',
#   'Lat': 54.4299,
#   'Lng': 31.8996,
#   'Max Temp': 42.85,
#   'Humidity': 80,
#   'Cloudiness': 17,
#   'Wind Speed': 9.37,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:08:02',
#   'Description': 'few clouds'},
#  {'City': 'Pangkalanbuun',
#   'Lat': -2.6833,
#   'Lng': 111.6167,
#   'Max Temp': 74.28,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.26,
#   'Country': 'ID',
#   'Date': '2021-10-30 21:06:30',
#   'Description': 'overcast clouds'},
#  {'City': 'Okha',
#   'Lat': 53.5739,
#   'Lng': 142.9478,
#   'Max Temp': 29.26,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 16.96,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:08:03',
#   'Description': 'overcast clouds'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 75.24,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-10-30 21:08:03',
#   'Description': 'clear sky'},
#  {'City': 'Campbell River',
#   'Lat': 50.0163,
#   'Lng': -125.2446,
#   'Max Temp': 48.25,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:08:04',
#   'Description': 'clear sky'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 61.43,
#   'Humidity': 91,
#   'Cloudiness': 32,
#   'Wind Speed': 1.16,
#   'Country': 'TL',
#   'Date': '2021-10-30 21:08:04',
#   'Description': 'scattered clouds'},
#  {'City': 'Sola',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 81.05,
#   'Humidity': 69,
#   'Cloudiness': 3,
#   'Wind Speed': 16.82,
#   'Country': 'VU',
#   'Date': '2021-10-30 21:08:04',
#   'Description': 'clear sky'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 70.74,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 16.37,
#   'Country': 'PT',
#   'Date': '2021-10-30 21:08:05',
#   'Description': 'overcast clouds'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 71.15,
#   'Humidity': 79,
#   'Cloudiness': 86,
#   'Wind Speed': 3.85,
#   'Country': 'RE',
#   'Date': '2021-10-30 21:08:05',
#   'Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 64.94,
#   'Humidity': 86,
#   'Cloudiness': 79,
#   'Wind Speed': 6.49,
#   'Country': 'ZA',
#   'Date': '2021-10-30 21:01:43',
#   'Description': 'broken clouds'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 74.17,
#   'Humidity': 85,
#   'Cloudiness': 93,
#   'Wind Speed': 6.62,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:08:06',
#   'Description': 'overcast clouds'},
#  {'City': 'Tezu',
#   'Lat': 27.9167,
#   'Lng': 96.1667,
#   'Max Temp': 66.99,
#   'Humidity': 49,
#   'Cloudiness': 38,
#   'Wind Speed': 3.36,
#   'Country': 'IN',
#   'Date': '2021-10-30 21:08:06',
#   'Description': 'scattered clouds'},
#  {'City': 'Guozhen',
#   'Lat': 34.3659,
#   'Lng': 107.359,
#   'Max Temp': 55.81,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Country': 'CN',
#   'Date': '2021-10-30 21:08:06',
#   'Description': 'light rain'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 36.7,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 15.99,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:08:07',
#   'Description': 'overcast clouds'},
#  {'City': 'Acari',
#   'Lat': -15.4311,
#   'Lng': -74.6158,
#   'Max Temp': 77.38,
#   'Humidity': 54,
#   'Cloudiness': 9,
#   'Wind Speed': 8.25,
#   'Country': 'PE',
#   'Date': '2021-10-30 21:08:07',
#   'Description': 'clear sky'},
#  {'City': 'Ilhabela',
#   'Lat': -23.7781,
#   'Lng': -45.3581,
#   'Max Temp': 69.82,
#   'Humidity': 92,
#   'Cloudiness': 97,
#   'Wind Speed': 12.68,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:08:08',
#   'Description': 'overcast clouds'},
#  {'City': 'Padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 77.36,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.98,
#   'Country': 'ID',
#   'Date': '2021-10-30 21:08:08',
#   'Description': 'heavy intensity rain'},
#  {'City': 'Dengfeng',
#   'Lat': 34.4553,
#   'Lng': 113.0281,
#   'Max Temp': 58.95,
#   'Humidity': 61,
#   'Cloudiness': 78,
#   'Wind Speed': 3.27,
#   'Country': 'CN',
#   'Date': '2021-10-30 21:08:09',
#   'Description': 'broken clouds'},
#  {'City': 'Flinders',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 55.8,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'AU',
#   'Date': '2021-10-30 21:08:10',
#   'Description': 'clear sky'},
#  {'City': 'Natal',
#   'Lat': -5.795,
#   'Lng': -35.2094,
#   'Max Temp': 81.25,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:03:53',
#   'Description': 'few clouds'},
#  {'City': 'Belmonte',
#   'Lat': -15.8631,
#   'Lng': -38.8828,
#   'Max Temp': 77.5,
#   'Humidity': 81,
#   'Cloudiness': 95,
#   'Wind Speed': 6.89,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:08:10',
#   'Description': 'overcast clouds'},
#  {'City': 'Shieli',
#   'Lat': 44.1667,
#   'Lng': 66.75,
#   'Max Temp': 41.94,
#   'Humidity': 53,
#   'Cloudiness': 22,
#   'Wind Speed': 7.83,
#   'Country': 'KZ',
#   'Date': '2021-10-30 21:08:11',
#   'Description': 'few clouds'},
#  {'City': 'Cherdyn',
#   'Lat': 60.403,
#   'Lng': 56.4787,
#   'Max Temp': 28.6,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.36,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:08:11',
#   'Description': 'overcast clouds'},
#  {'City': 'Ca Mau',
#   'Lat': 9.1769,
#   'Lng': 105.15,
#   'Max Temp': 76.17,
#   'Humidity': 96,
#   'Cloudiness': 93,
#   'Wind Speed': 4.63,
#   'Country': 'VN',
#   'Date': '2021-10-30 21:08:11',
#   'Description': 'overcast clouds'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 79.07,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 4.54,
#   'Country': 'VU',
#   'Date': '2021-10-30 21:08:12',
#   'Description': 'clear sky'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 82.87,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2021-10-30 21:04:12',
#   'Description': 'clear sky'},
#  {'City': 'Beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 67.55,
#   'Humidity': 82,
#   'Cloudiness': 38,
#   'Wind Speed': 11.68,
#   'Country': 'MG',
#   'Date': '2021-10-30 21:07:19',
#   'Description': 'scattered clouds'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 82.65,
#   'Humidity': 77,
#   'Cloudiness': 50,
#   'Wind Speed': 12.86,
#   'Country': 'PG',
#   'Date': '2021-10-30 20:56:01',
#   'Description': 'light rain'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 79.9,
#   'Humidity': 75,
#   'Cloudiness': 78,
#   'Wind Speed': 11.74,
#   'Country': 'CV',
#   'Date': '2021-10-30 21:08:13',
#   'Description': 'broken clouds'},
#  {'City': 'Estelle',
#   'Lat': 29.8458,
#   'Lng': -90.1067,
#   'Max Temp': 70.05,
#   'Humidity': 59,
#   'Cloudiness': 1,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2021-10-30 21:08:13',
#   'Description': 'clear sky'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 1.13,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.77,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:08:13',
#   'Description': 'overcast clouds'},
#  {'City': 'Prince Rupert',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 47.71,
#   'Humidity': 51,
#   'Cloudiness': 85,
#   'Wind Speed': 2.33,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:04:34',
#   'Description': 'overcast clouds'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 47.01,
#   'Humidity': 92,
#   'Cloudiness': 97,
#   'Wind Speed': 7.63,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:08:14',
#   'Description': 'overcast clouds'},
#  {'City': 'Berasia',
#   'Lat': 23.6333,
#   'Lng': 77.4333,
#   'Max Temp': 63.07,
#   'Humidity': 54,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Country': 'IN',
#   'Date': '2021-10-30 21:08:15',
#   'Description': 'scattered clouds'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 60.37,
#   'Humidity': 90,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Date': '2021-10-30 21:07:54',
#   'Description': 'broken clouds'},
#  {'City': 'Amargosa',
#   'Lat': -13.0303,
#   'Lng': -39.6047,
#   'Max Temp': 72.01,
#   'Humidity': 78,
#   'Cloudiness': 66,
#   'Wind Speed': 8.57,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:07:50',
#   'Description': 'broken clouds'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 64.81,
#   'Humidity': 85,
#   'Cloudiness': 80,
#   'Wind Speed': 7.4,
#   'Country': 'ZA',
#   'Date': '2021-10-30 20:55:48',
#   'Description': 'broken clouds'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 43.68,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 8.93,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:08:17',
#   'Description': 'clear sky'},
#  {'City': 'Varzea Da Palma',
#   'Lat': -17.5981,
#   'Lng': -44.7308,
#   'Max Temp': 75.78,
#   'Humidity': 67,
#   'Cloudiness': 80,
#   'Wind Speed': 5.82,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:08:17',
#   'Description': 'broken clouds'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 75.81,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'ID',
#   'Date': '2021-10-30 21:08:18',
#   'Description': 'overcast clouds'},
#  {'City': 'Moron',
#   'Lat': -34.6534,
#   'Lng': -58.6198,
#   'Max Temp': 89.02,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'AR',
#   'Date': '2021-10-30 21:08:18',
#   'Description': 'clear sky'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -0.96,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.77,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:08:18',
#   'Description': 'overcast clouds'},
#  {'City': 'Svetlogorsk',
#   'Lat': 52.6333,
#   'Lng': 29.7333,
#   'Max Temp': 43.63,
#   'Humidity': 76,
#   'Cloudiness': 35,
#   'Wind Speed': 9.55,
#   'Country': 'BY',
#   'Date': '2021-10-30 21:08:19',
#   'Description': 'scattered clouds'},
#  {'City': 'Howard Springs',
#   'Lat': -12.497,
#   'Lng': 131.047,
#   'Max Temp': 80.51,
#   'Humidity': 96,
#   'Cloudiness': 74,
#   'Wind Speed': 3.56,
#   'Country': 'AU',
#   'Date': '2021-10-30 21:08:19',
#   'Description': 'broken clouds'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 61.9,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 8.46,
#   'Country': 'ZA',
#   'Date': '2021-10-30 20:56:17',
#   'Description': 'broken clouds'},
#  {'City': 'Labuhan',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 79.65,
#   'Humidity': 83,
#   'Cloudiness': 88,
#   'Wind Speed': 4.38,
#   'Country': 'ID',
#   'Date': '2021-10-30 21:08:20',
#   'Description': 'overcast clouds'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 75.25,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'CK',
#   'Date': '2021-10-30 21:08:21',
#   'Description': 'few clouds'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 61.18,
#   'Humidity': 54,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Country': 'US',
#   'Date': '2021-10-30 21:08:21',
#   'Description': 'clear sky'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 68.47,
#   'Humidity': 86,
#   'Cloudiness': 28,
#   'Wind Speed': 22.84,
#   'Country': 'BR',
#   'Date': '2021-10-30 20:59:30',
#   'Description': 'scattered clouds'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 33.1,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 8.84,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:08:22',
#   'Description': 'snow'},
#  {'City': 'Chernyshevskiy',
#   'Lat': 63.0128,
#   'Lng': 112.4714,
#   'Max Temp': 28.4,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 9.73,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:08:22',
#   'Description': 'light snow'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 47.35,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.14,
#   'Country': 'NZ',
#   'Date': '2021-10-30 21:08:23',
#   'Description': 'overcast clouds'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 64.47,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'AU',
#   'Date': '2021-10-30 21:08:23',
#   'Description': 'clear sky'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 58.28,
#   'Humidity': 96,
#   'Cloudiness': 67,
#   'Wind Speed': 4.09,
#   'Country': 'ZA',
#   'Date': '2021-10-30 21:08:23',
#   'Description': 'broken clouds'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 82.47,
#   'Humidity': 83,
#   'Cloudiness': 10,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-10-30 20:56:42',
#   'Description': 'clear sky'},
#  {'City': 'Nortelandia',
#   'Lat': -14.4547,
#   'Lng': -56.8028,
#   'Max Temp': 89.73,
#   'Humidity': 47,
#   'Cloudiness': 70,
#   'Wind Speed': 2.37,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:08:24',
#   'Description': 'broken clouds'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 59.13,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 2.62,
#   'Country': 'CL',
#   'Date': '2021-10-30 21:00:35',
#   'Description': 'clear sky'},
#  {'City': 'Rio Grande',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 75.31,
#   'Humidity': 82,
#   'Cloudiness': 73,
#   'Wind Speed': 19.91,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:08:25',
#   'Description': 'broken clouds'},
#  {'City': 'Visnes',
#   'Lat': 59.3556,
#   'Lng': 5.2242,
#   'Max Temp': 55.29,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 19.57,
#   'Country': 'NO',
#   'Date': '2021-10-30 21:08:25',
#   'Description': 'light rain'},
#  {'City': 'Goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 52.92,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 10.83,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:08:25',
#   'Description': 'overcast clouds'},
#  {'City': 'Pierre',
#   'Lat': 44.3683,
#   'Lng': -100.351,
#   'Max Temp': 52.86,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Date': '2021-10-30 21:05:43',
#   'Description': 'broken clouds'},
#  {'City': 'Den Helder',
#   'Lat': 52.9599,
#   'Lng': 4.7593,
#   'Max Temp': 55.38,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 10,
#   'Country': 'NL',
#   'Date': '2021-10-30 21:03:47',
#   'Description': 'overcast clouds'},
#  {'City': 'Alyangula',
#   'Lat': -13.8483,
#   'Lng': 136.4192,
#   'Max Temp': 81,
#   'Humidity': 78,
#   'Cloudiness': 63,
#   'Wind Speed': 5.14,
#   'Country': 'AU',
#   'Date': '2021-10-30 21:06:58',
#   'Description': 'broken clouds'},
#  {'City': 'Verkhoyansk',
#   'Lat': 67.5447,
#   'Lng': 133.385,
#   'Max Temp': -14.31,
#   'Humidity': 100,
#   'Cloudiness': 53,
#   'Wind Speed': 2.46,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:06:58',
#   'Description': 'broken clouds'},
#  {'City': 'Yaan',
#   'Lat': 7.3833,
#   'Lng': 8.5667,
#   'Max Temp': 77.86,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 4.79,
#   'Country': 'NG',
#   'Date': '2021-10-30 21:08:28',
#   'Description': 'overcast clouds'},
#  {'City': 'Strelka',
#   'Lat': 58.0728,
#   'Lng': 93.0344,
#   'Max Temp': 26.44,
#   'Humidity': 60,
#   'Cloudiness': 98,
#   'Wind Speed': 7.94,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:08:28',
#   'Description': 'overcast clouds'},
#  {'City': 'Mogadishu',
#   'Lat': 2.0371,
#   'Lng': 45.3438,
#   'Max Temp': 79.03,
#   'Humidity': 79,
#   'Cloudiness': 18,
#   'Wind Speed': 14.25,
#   'Country': 'SO',
#   'Date': '2021-10-30 21:08:28',
#   'Description': 'few clouds'},
#  {'City': 'Alugan',
#   'Lat': 12.2188,
#   'Lng': 125.4808,
#   'Max Temp': 81.05,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 17.05,
#   'Country': 'PH',
#   'Date': '2021-10-30 21:08:29',
#   'Description': 'overcast clouds'},
#  {'City': 'Lere',
#   'Lat': 10.387,
#   'Lng': 8.5726,
#   'Max Temp': 73.31,
#   'Humidity': 31,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'NG',
#   'Date': '2021-10-30 21:08:29',
#   'Description': 'overcast clouds'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 75.33,
#   'Humidity': 83,
#   'Cloudiness': 97,
#   'Wind Speed': 1.01,
#   'Country': 'HK',
#   'Date': '2021-10-30 21:06:12',
#   'Description': 'overcast clouds'},
#  {'City': 'Parabel',
#   'Lat': 58.6978,
#   'Lng': 81.4825,
#   'Max Temp': 24.26,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 7.58,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:08:30',
#   'Description': 'overcast clouds'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 60.75,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'CL',
#   'Date': '2021-10-30 21:08:31',
#   'Description': 'clear sky'},
#  {'City': 'Macau',
#   'Lat': 22.2006,
#   'Lng': 113.5461,
#   'Max Temp': 75.07,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Country': 'MO',
#   'Date': '2021-10-30 21:06:03',
#   'Description': 'scattered clouds'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 13.08,
#   'Humidity': 80,
#   'Cloudiness': 89,
#   'Wind Speed': 10.67,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:08:31',
#   'Description': 'overcast clouds'},
#  {'City': 'Kanker',
#   'Lat': 20.2719,
#   'Lng': 81.4931,
#   'Max Temp': 66.96,
#   'Humidity': 88,
#   'Cloudiness': 57,
#   'Wind Speed': 0.49,
#   'Country': 'IN',
#   'Date': '2021-10-30 21:08:32',
#   'Description': 'broken clouds'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 65.95,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'ES',
#   'Date': '2021-10-30 21:08:32',
#   'Description': 'clear sky'},
#  {'City': 'Aguimes',
#   'Lat': 27.9054,
#   'Lng': -15.4461,
#   'Max Temp': 66.83,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'ES',
#   'Date': '2021-10-30 21:08:32',
#   'Description': 'few clouds'},
#  {'City': 'Kimbe',
#   'Lat': -5.5502,
#   'Lng': 150.1429,
#   'Max Temp': 79.39,
#   'Humidity': 84,
#   'Cloudiness': 30,
#   'Wind Speed': 3.58,
#   'Country': 'PG',
#   'Date': '2021-10-30 21:08:34',
#   'Description': 'scattered clouds'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 42.78,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 13,
#   'Country': 'IS',
#   'Date': '2021-10-30 21:08:34',
#   'Description': 'overcast clouds'},
#  {'City': 'Calatayud',
#   'Lat': 41.3535,
#   'Lng': -1.6432,
#   'Max Temp': 66.78,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 7.07,
#   'Country': 'ES',
#   'Date': '2021-10-30 21:08:35',
#   'Description': 'overcast clouds'},
#  {'City': 'Nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 49.57,
#   'Humidity': 76,
#   'Cloudiness': 56,
#   'Wind Speed': 10.78,
#   'Country': 'JP',
#   'Date': '2021-10-30 21:08:35',
#   'Description': 'broken clouds'},
#  {'City': 'Harboore',
#   'Lat': 56.6175,
#   'Lng': 8.1807,
#   'Max Temp': 53.22,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 22.79,
#   'Country': 'DK',
#   'Date': '2021-10-30 21:08:36',
#   'Description': 'overcast clouds'},
#  {'City': 'Buraydah',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 74.98,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 13.56,
#   'Country': 'SA',
#   'Date': '2021-10-30 21:04:46',
#   'Description': 'clear sky'},
#  {'City': 'Fiumicino',
#   'Lat': 41.7675,
#   'Lng': 12.2291,
#   'Max Temp': 63.03,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'IT',
#   'Date': '2021-10-30 21:08:36',
#   'Description': 'clear sky'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 68.2,
#   'Humidity': 72,
#   'Cloudiness': 82,
#   'Wind Speed': 7.74,
#   'Country': 'AO',
#   'Date': '2021-10-30 21:08:37',
#   'Description': 'broken clouds'},
#  {'City': 'Zomba',
#   'Lat': -15.386,
#   'Lng': 35.3188,
#   'Max Temp': 72.18,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 2.95,
#   'Country': 'MW',
#   'Date': '2021-10-30 21:08:37',
#   'Description': 'clear sky'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 40.5,
#   'Humidity': 86,
#   'Cloudiness': 78,
#   'Wind Speed': 11.41,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:08:37',
#   'Description': 'broken clouds'},
#  {'City': 'Terra Boa',
#   'Lat': -23.7681,
#   'Lng': -52.4442,
#   'Max Temp': 73.17,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 5.3,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:08:38',
#   'Description': 'moderate rain'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 64.36,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 1.99,
#   'Country': 'US',
#   'Date': '2021-10-30 21:08:38',
#   'Description': 'few clouds'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 75.38,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 2.91,
#   'Country': 'VE',
#   'Date': '2021-10-30 21:08:39',
#   'Description': 'light rain'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 89.51,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 14.97,
#   'Country': 'MX',
#   'Date': '2021-10-30 21:08:39',
#   'Description': 'few clouds'},
#  {'City': 'Biliran',
#   'Lat': 11.4667,
#   'Lng': 124.4753,
#   'Max Temp': 77.4,
#   'Humidity': 89,
#   'Cloudiness': 98,
#   'Wind Speed': 7.61,
#   'Country': 'PH',
#   'Date': '2021-10-30 21:08:40',
#   'Description': 'overcast clouds'},
#  {'City': 'Grindavik',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 37.87,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'IS',
#   'Date': '2021-10-30 21:08:40',
#   'Description': 'clear sky'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 52.2,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 6.49,
#   'Country': 'JP',
#   'Date': '2021-10-30 21:08:40',
#   'Description': 'broken clouds'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 49.71,
#   'Humidity': 46,
#   'Cloudiness': 100,
#   'Wind Speed': 1.74,
#   'Country': 'UZ',
#   'Date': '2021-10-30 21:08:41',
#   'Description': 'overcast clouds'},
#  {'City': 'Horsham',
#   'Lat': 51.064,
#   'Lng': -0.3272,
#   'Max Temp': 52.92,
#   'Humidity': 75,
#   'Cloudiness': 33,
#   'Wind Speed': 2.3,
#   'Country': 'GB',
#   'Date': '2021-10-30 21:08:41',
#   'Description': 'scattered clouds'},
#  {'City': 'Baie-Comeau',
#   'Lat': 49.2168,
#   'Lng': -68.1489,
#   'Max Temp': 48.09,
#   'Humidity': 72,
#   'Cloudiness': 55,
#   'Wind Speed': 5.73,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:08:42',
#   'Description': 'broken clouds'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 69.46,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 21.47,
#   'Country': 'PT',
#   'Date': '2021-10-30 21:08:42',
#   'Description': 'overcast clouds'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 17.8,
#   'Humidity': 83,
#   'Cloudiness': 95,
#   'Wind Speed': 2.62,
#   'Country': 'SJ',
#   'Date': '2021-10-30 21:08:43',
#   'Description': 'overcast clouds'},
#  {'City': 'Soyaux',
#   'Lat': 45.65,
#   'Lng': 0.2,
#   'Max Temp': 57.67,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'FR',
#   'Date': '2021-10-30 21:08:43',
#   'Description': 'clear sky'},
#  {'City': 'Ambon',
#   'Lat': -3.6954,
#   'Lng': 128.1814,
#   'Max Temp': 81.23,
#   'Humidity': 74,
#   'Cloudiness': 73,
#   'Wind Speed': 2.66,
#   'Country': 'ID',
#   'Date': '2021-10-30 21:08:43',
#   'Description': 'broken clouds'},
#  {'City': 'Gombe',
#   'Lat': 10.2897,
#   'Lng': 11.1673,
#   'Max Temp': 81.75,
#   'Humidity': 28,
#   'Cloudiness': 100,
#   'Wind Speed': 2.46,
#   'Country': 'NG',
#   'Date': '2021-10-30 21:08:44',
#   'Description': 'overcast clouds'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 70.09,
#   'Humidity': 78,
#   'Cloudiness': 38,
#   'Wind Speed': 7.27,
#   'Country': 'MU',
#   'Date': '2021-10-30 21:08:44',
#   'Description': 'scattered clouds'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 63.21,
#   'Humidity': 86,
#   'Cloudiness': 70,
#   'Wind Speed': 7.34,
#   'Country': 'ZA',
#   'Date': '2021-10-30 21:00:37',
#   'Description': 'broken clouds'},
#  {'City': 'Nyurba',
#   'Lat': 63.2842,
#   'Lng': 118.3319,
#   'Max Temp': 22.6,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 8.48,
#   'Country': 'RU',
#   'Date': '2021-10-30 20:57:24',
#   'Description': 'light snow'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.44,
#   'Humidity': 72,
#   'Cloudiness': 29,
#   'Wind Speed': 6.11,
#   'Country': 'KI',
#   'Date': '2021-10-30 21:08:45',
#   'Description': 'scattered clouds'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 87.64,
#   'Humidity': 20,
#   'Cloudiness': 89,
#   'Wind Speed': 11.52,
#   'Country': 'ML',
#   'Date': '2021-10-30 21:08:46',
#   'Description': 'overcast clouds'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 78.08,
#   'Humidity': 66,
#   'Cloudiness': 4,
#   'Wind Speed': 16.06,
#   'Country': 'PF',
#   'Date': '2021-10-30 21:08:12',
#   'Description': 'clear sky'},
#  {'City': 'Bud',
#   'Lat': 39.447,
#   'Lng': -86.1758,
#   'Max Temp': 56.7,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 10.13,
#   'Country': 'US',
#   'Date': '2021-10-30 21:08:46',
#   'Description': 'overcast clouds'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 48.09,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Date': '2021-10-30 21:08:47',
#   'Description': 'broken clouds'},
#  {'City': 'Alihe',
#   'Lat': 50.5667,
#   'Lng': 123.7167,
#   'Max Temp': 25.02,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 1.66,
#   'Country': 'CN',
#   'Date': '2021-10-30 21:08:47',
#   'Description': 'clear sky'},
#  {'City': 'Honningsvag',
#   'Lat': 70.9821,
#   'Lng': 25.9704,
#   'Max Temp': 41.58,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 8.39,
#   'Country': 'NO',
#   'Date': '2021-10-30 21:08:48',
#   'Description': 'overcast clouds'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 78.89,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'OM',
#   'Date': '2021-10-30 21:08:48',
#   'Description': 'clear sky'},
#  {'City': 'Angouleme',
#   'Lat': 45.65,
#   'Lng': 0.15,
#   'Max Temp': 58.03,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'FR',
#   'Date': '2021-10-30 21:08:49',
#   'Description': 'clear sky'},
#  {'City': 'Eutin',
#   'Lat': 54.1333,
#   'Lng': 10.6167,
#   'Max Temp': 53.78,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 14.07,
#   'Country': 'DE',
#   'Date': '2021-10-30 21:08:49',
#   'Description': 'overcast clouds'},
#  {'City': 'Socorro',
#   'Lat': 31.6546,
#   'Lng': -106.3033,
#   'Max Temp': 83.07,
#   'Humidity': 14,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Date': '2021-10-30 21:08:50',
#   'Description': 'clear sky'},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 5.79,
#   'Humidity': 97,
#   'Cloudiness': 97,
#   'Wind Speed': 17.85,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:08:50',
#   'Description': 'overcast clouds'},
#  {'City': 'Hinton',
#   'Lat': 53.4001,
#   'Lng': -117.5857,
#   'Max Temp': 41.11,
#   'Humidity': 25,
#   'Cloudiness': 1,
#   'Wind Speed': 3.78,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:08:51',
#   'Description': 'clear sky'},
#  {'City': 'Pedra',
#   'Lat': -8.4969,
#   'Lng': -36.9408,
#   'Max Temp': 79.81,
#   'Humidity': 43,
#   'Cloudiness': 26,
#   'Wind Speed': 9.13,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:08:51',
#   'Description': 'scattered clouds'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 82.44,
#   'Humidity': 79,
#   'Cloudiness': 89,
#   'Wind Speed': 6.8,
#   'Country': 'PG',
#   'Date': '2021-10-30 21:08:52',
#   'Description': 'overcast clouds'},
# ...
#   'Max Temp': 62.06,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 7,
#   'Country': 'US',
#   'Date': '2021-10-30 21:11:00',
#   'Description': 'overcast clouds'},
#  {'City': 'Kolyvan',
#   'Lat': 55.3053,
#   'Lng': 82.7391,
#   'Max Temp': 23.05,
#   'Humidity': 50,
#   'Cloudiness': 100,
#   'Wind Speed': 8.72,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:11:46',
#   'Description': 'overcast clouds'},
#  {'City': 'Khoy',
#   'Lat': 38.5504,
#   'Lng': 44.9535,
#   'Max Temp': 50.5,
#   'Humidity': 70,
#   'Cloudiness': 99,
#   'Wind Speed': 1.66,
#   'Country': 'IR',
#   'Date': '2021-10-30 21:11:46',
#   'Description': 'overcast clouds'},
#  {'City': 'Huarmey',
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 68.34,
#   'Humidity': 74,
#   'Cloudiness': 51,
#   'Wind Speed': 9.06,
#   'Country': 'PE',
#   'Date': '2021-10-30 21:11:46',
#   'Description': 'broken clouds'},
#  {'City': 'Centralia',
#   'Lat': 46.7162,
#   'Lng': -122.9543,
#   'Max Temp': 57.69,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Date': '2021-10-30 21:11:47',
#   'Description': 'clear sky'},
#  {'City': 'Kaa-Khem',
#   'Lat': 51.6833,
#   'Lng': 94.7333,
#   'Max Temp': 34.52,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 2.77,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:11:47',
#   'Description': 'overcast clouds'},
#  {'City': 'Inirida',
#   'Lat': 3.8653,
#   'Lng': -67.9239,
#   'Max Temp': 77.83,
#   'Humidity': 94,
#   'Cloudiness': 88,
#   'Wind Speed': 3.83,
#   'Country': 'CO',
#   'Date': '2021-10-30 21:11:49',
#   'Description': 'overcast clouds'},
#  {'City': 'Kamyzyak',
#   'Lat': 46.11,
#   'Lng': 48.0736,
#   'Max Temp': 39.18,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:11:49',
#   'Description': 'clear sky'},
#  {'City': 'Doha',
#   'Lat': 25.2867,
#   'Lng': 51.5333,
#   'Max Temp': 80.58,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'QA',
#   'Date': '2021-10-30 21:11:50',
#   'Description': 'clear sky'},
#  {'City': 'Kulhudhuffushi',
#   'Lat': 6.6221,
#   'Lng': 73.07,
#   'Max Temp': 80.04,
#   'Humidity': 81,
#   'Cloudiness': 93,
#   'Wind Speed': 7.63,
#   'Country': 'MV',
#   'Date': '2021-10-30 21:11:50',
#   'Description': 'overcast clouds'},
#  {'City': 'Biggar',
#   'Lat': 55.6167,
#   'Lng': -3.5167,
#   'Max Temp': 45.12,
#   'Humidity': 94,
#   'Cloudiness': 34,
#   'Wind Speed': 7.43,
#   'Country': 'GB',
#   'Date': '2021-10-30 21:11:50',
#   'Description': 'scattered clouds'},
#  {'City': 'Vilyuysk',
#   'Lat': 63.7553,
#   'Lng': 121.6247,
#   'Max Temp': 13.64,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 9.98,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:11:51',
#   'Description': 'overcast clouds'},
#  {'City': 'El Seibo',
#   'Lat': 18.7641,
#   'Lng': -69.0375,
#   'Max Temp': 85.53,
#   'Humidity': 73,
#   'Cloudiness': 39,
#   'Wind Speed': 5.77,
#   'Country': 'DO',
#   'Date': '2021-10-30 21:11:51',
#   'Description': 'scattered clouds'},
#  {'City': 'Shelburne',
#   'Lat': 44.0787,
#   'Lng': -80.2041,
#   'Max Temp': 45.84,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 8.46,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:11:51',
#   'Description': 'overcast clouds'},
#  {'City': 'Donskoye',
#   'Lat': 45.4552,
#   'Lng': 41.9741,
#   'Max Temp': 44.73,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 12.1,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:11:53',
#   'Description': 'clear sky'},
#  {'City': 'Mbini',
#   'Lat': 1.574,
#   'Lng': 9.6134,
#   'Max Temp': 78.06,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 5.21,
#   'Country': 'GQ',
#   'Date': '2021-10-30 21:11:54',
#   'Description': 'light rain'},
#  {'City': 'Canakkale',
#   'Lat': 40.0833,
#   'Lng': 26.8333,
#   'Max Temp': 52.41,
#   'Humidity': 79,
#   'Cloudiness': 84,
#   'Wind Speed': 9.8,
#   'Country': 'TR',
#   'Date': '2021-10-30 21:11:54',
#   'Description': 'broken clouds'},
#  {'City': 'Anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 1,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 17,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:11:55',
#   'Description': 'overcast clouds'},
#  {'City': 'Corn Island',
#   'Lat': 12.1694,
#   'Lng': -83.0418,
#   'Max Temp': 82.54,
#   'Humidity': 77,
#   'Cloudiness': 98,
#   'Wind Speed': 20.49,
#   'Country': 'NI',
#   'Date': '2021-10-30 21:11:55',
#   'Description': 'overcast clouds'},
#  {'City': 'Zykovo',
#   'Lat': 55.9519,
#   'Lng': 93.1461,
#   'Max Temp': 25.54,
#   'Humidity': 62,
#   'Cloudiness': 91,
#   'Wind Speed': 6.46,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:11:55',
#   'Description': 'overcast clouds'},
#  {'City': 'Moroni',
#   'Lat': -11.7022,
#   'Lng': 43.2551,
#   'Max Temp': 76.06,
#   'Humidity': 79,
#   'Cloudiness': 3,
#   'Wind Speed': 3.38,
#   'Country': 'KM',
#   'Date': '2021-10-30 21:11:56',
#   'Description': 'clear sky'},
#  {'City': 'Queanbeyan',
#   'Lat': -35.35,
#   'Lng': 149.2333,
#   'Max Temp': 51.3,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 2.3,
#   'Country': 'AU',
#   'Date': '2021-10-30 21:11:56',
#   'Description': 'clear sky'},
#  {'City': 'Snezhnogorsk',
#   'Lat': 69.1933,
#   'Lng': 33.2531,
#   'Max Temp': 22.78,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.38,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:11:57',
#   'Description': 'overcast clouds'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 40.95,
#   'Humidity': 95,
#   'Cloudiness': 0,
#   'Wind Speed': 1.25,
#   'Country': 'RO',
#   'Date': '2021-10-30 21:11:57',
#   'Description': 'clear sky'},
#  {'City': 'Waipawa',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 61.45,
#   'Humidity': 51,
#   'Cloudiness': 9,
#   'Wind Speed': 14.65,
#   'Country': 'NZ',
#   'Date': '2021-10-30 21:11:58',
#   'Description': 'clear sky'},
#  {'City': 'Solnechnyy',
#   'Lat': 50.7214,
#   'Lng': 136.6319,
#   'Max Temp': 25.38,
#   'Humidity': 79,
#   'Cloudiness': 83,
#   'Wind Speed': 6.55,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:11:58',
#   'Description': 'broken clouds'},
#  {'City': 'Sarankhola',
#   'Lat': 22.3082,
#   'Lng': 89.7897,
#   'Max Temp': 70.45,
#   'Humidity': 80,
#   'Cloudiness': 95,
#   'Wind Speed': 5.21,
#   'Country': 'BD',
#   'Date': '2021-10-30 21:11:59',
#   'Description': 'overcast clouds'},
#  {'City': 'North Bend',
#   'Lat': 43.4065,
#   'Lng': -124.2243,
#   'Max Temp': 61.92,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Date': '2021-10-30 21:11:59',
#   'Description': 'overcast clouds'},
#  {'City': 'Hobyo',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 80.31,
#   'Humidity': 69,
#   'Cloudiness': 7,
#   'Wind Speed': 14.7,
#   'Country': 'SO',
#   'Date': '2021-10-30 21:11:59',
#   'Description': 'clear sky'},
#  {'City': 'Moscow',
#   'Lat': 55.7522,
#   'Lng': 37.6156,
#   'Max Temp': 45.37,
#   'Humidity': 84,
#   'Cloudiness': 15,
#   'Wind Speed': 9.51,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:11:25',
#   'Description': 'few clouds'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 38.75,
#   'Humidity': 74,
#   'Cloudiness': 94,
#   'Wind Speed': 7.7,
#   'Country': 'NO',
#   'Date': '2021-10-30 21:12:00',
#   'Description': 'overcast clouds'},
#  {'City': 'Ust-Uda',
#   'Lat': 54.1742,
#   'Lng': 103.0304,
#   'Max Temp': 30.49,
#   'Humidity': 87,
#   'Cloudiness': 85,
#   'Wind Speed': 3.74,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:12:01',
#   'Description': 'overcast clouds'},
#  {'City': 'Puerto Palomas',
#   'Lat': 31.7667,
#   'Lng': -107.6167,
#   'Max Temp': 83.53,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 11.59,
#   'Country': 'MX',
#   'Date': '2021-10-30 21:12:01',
#   'Description': 'clear sky'},
#  {'City': 'Ust-Barguzin',
#   'Lat': 53.45,
#   'Lng': 108.9833,
#   'Max Temp': 27.09,
#   'Humidity': 64,
#   'Cloudiness': 99,
#   'Wind Speed': 5.06,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:12:02',
#   'Description': 'overcast clouds'},
#  {'City': 'Ripoll',
#   'Lat': 42.2006,
#   'Lng': 2.1903,
#   'Max Temp': 60.13,
#   'Humidity': 85,
#   'Cloudiness': 98,
#   'Wind Speed': 2.46,
#   'Country': 'ES',
#   'Date': '2021-10-30 21:12:03',
#   'Description': 'overcast clouds'},
#  {'City': 'Abha',
#   'Lat': 18.2164,
#   'Lng': 42.5053,
#   'Max Temp': 59.25,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'SA',
#   'Date': '2021-10-30 21:12:03',
#   'Description': 'clear sky'},
#  {'City': 'Iralaya',
#   'Lat': 15,
#   'Lng': -83.2333,
#   'Max Temp': 82.49,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 15.66,
#   'Country': 'HN',
#   'Date': '2021-10-30 21:12:03',
#   'Description': 'overcast clouds'},
#  {'City': 'Andros Town',
#   'Lat': 24.7,
#   'Lng': -77.7667,
#   'Max Temp': 80.56,
#   'Humidity': 58,
#   'Cloudiness': 84,
#   'Wind Speed': 18.43,
#   'Country': 'BS',
#   'Date': '2021-10-30 21:12:04',
#   'Description': 'broken clouds'},
#  {'City': 'Shingu',
#   'Lat': 33.7333,
#   'Lng': 135.9833,
#   'Max Temp': 60.06,
#   'Humidity': 81,
#   'Cloudiness': 82,
#   'Wind Speed': 5.82,
#   'Country': 'JP',
#   'Date': '2021-10-30 21:12:04',
#   'Description': 'light rain'},
#  {'City': 'Vao',
#   'Lat': -22.6667,
#   'Lng': 167.4833,
#   'Max Temp': 70.9,
#   'Humidity': 74,
#   'Cloudiness': 2,
#   'Wind Speed': 5.61,
#   'Country': 'NC',
#   'Date': '2021-10-30 21:12:04',
#   'Description': 'clear sky'},
#  {'City': 'Almora',
#   'Lat': 29.6167,
#   'Lng': 79.6667,
#   'Max Temp': 47.43,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 1.45,
#   'Country': 'IN',
#   'Date': '2021-10-30 21:12:05',
#   'Description': 'clear sky'},
#  {'City': 'Daru',
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp': 80.08,
#   'Humidity': 85,
#   'Cloudiness': 96,
#   'Wind Speed': 8.41,
#   'Country': 'PG',
#   'Date': '2021-10-30 21:12:05',
#   'Description': 'overcast clouds'},
#  {'City': 'Wanaka',
#   'Lat': -44.7,
#   'Lng': 169.15,
#   'Max Temp': 47.34,
#   'Humidity': 88,
#   'Cloudiness': 83,
#   'Wind Speed': 7.29,
#   'Country': 'NZ',
#   'Date': '2021-10-30 21:12:06',
#   'Description': 'moderate rain'},
#  {'City': 'Santa Rosa',
#   'Lat': 14.3122,
#   'Lng': 121.1114,
#   'Max Temp': 80.85,
#   'Humidity': 74,
#   'Cloudiness': 66,
#   'Wind Speed': 12.53,
#   'Country': 'PH',
#   'Date': '2021-10-30 21:09:09',
#   'Description': 'broken clouds'},
#  {'City': 'Gari',
#   'Lat': 59.4307,
#   'Lng': 62.3497,
#   'Max Temp': 18.1,
#   'Humidity': 97,
#   'Cloudiness': 44,
#   'Wind Speed': 5.88,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:12:06',
#   'Description': 'scattered clouds'},
#  {'City': 'Cam Ranh',
#   'Lat': 11.9214,
#   'Lng': 109.1591,
#   'Max Temp': 76.96,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'VN',
#   'Date': '2021-10-30 21:12:07',
#   'Description': 'thunderstorm with light rain'},
#  {'City': 'Mucurapo',
#   'Lat': 10.6667,
#   'Lng': -61.5333,
#   'Max Temp': 84.25,
#   'Humidity': 83,
#   'Cloudiness': 67,
#   'Wind Speed': 9.6,
#   'Country': 'TT',
#   'Date': '2021-10-30 21:12:07',
#   'Description': 'broken clouds'},
#  {'City': 'Yerbogachen',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': 33.21,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 13.76,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:12:08',
#   'Description': 'overcast clouds'},
#  {'City': 'Zhezkazgan',
#   'Lat': 47.8043,
#   'Lng': 67.7144,
#   'Max Temp': 43,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 14.18,
#   'Country': 'KZ',
#   'Date': '2021-10-30 21:12:08',
#   'Description': 'overcast clouds'},
#  {'City': 'Florence',
#   'Lat': 43.7667,
#   'Lng': 11.25,
#   'Max Temp': 62.24,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
#   'Country': 'IT',
#   'Date': '2021-10-30 21:07:51',
#   'Description': 'clear sky'},
#  {'City': 'Zheleznodorozhnyy',
#   'Lat': 55.7503,
#   'Lng': 38.0042,
#   'Max Temp': 45.36,
#   'Humidity': 83,
#   'Cloudiness': 16,
#   'Wind Speed': 8.43,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:12:09',
#   'Description': 'few clouds'},
#  {'City': 'Bikaner',
#   'Lat': 28.0167,
#   'Lng': 73.3,
#   'Max Temp': 75.65,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 7.94,
#   'Country': 'IN',
#   'Date': '2021-10-30 21:12:09',
#   'Description': 'clear sky'},
#  {'City': 'Bani Walid',
#   'Lat': 31.7566,
#   'Lng': 13.9942,
#   'Max Temp': 70.12,
#   'Humidity': 52,
#   'Cloudiness': 79,
#   'Wind Speed': 6.85,
#   'Country': 'LY',
#   'Date': '2021-10-30 21:12:10',
#   'Description': 'broken clouds'},
#  {'City': 'Kudat',
#   'Lat': 6.8837,
#   'Lng': 116.8477,
#   'Max Temp': 79.07,
#   'Humidity': 87,
#   'Cloudiness': 86,
#   'Wind Speed': 5.75,
#   'Country': 'MY',
#   'Date': '2021-10-30 21:12:10',
#   'Description': 'overcast clouds'},
#  {'City': 'Cedar City',
#   'Lat': 37.6775,
#   'Lng': -113.0619,
#   'Max Temp': 67.17,
#   'Humidity': 30,
#   'Cloudiness': 1,
#   'Wind Speed': 17.27,
#   'Country': 'US',
#   'Date': '2021-10-30 21:12:03',
#   'Description': 'clear sky'},
#  {'City': 'Ponta Delgada',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 73.51,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'PT',
#   'Date': '2021-10-30 21:12:11',
#   'Description': 'broken clouds'},
#  {'City': 'Neiafu',
#   'Lat': -18.65,
#   'Lng': -173.9833,
#   'Max Temp': 79.48,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'TO',
#   'Date': '2021-10-30 21:12:11',
#   'Description': 'scattered clouds'},
#  {'City': 'Vacha',
#   'Lat': 55.8008,
#   'Lng': 42.7706,
#   'Max Temp': 44.76,
#   'Humidity': 95,
#   'Cloudiness': 72,
#   'Wind Speed': 8.61,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:12:12',
#   'Description': 'broken clouds'},
#  {'City': 'Huntingdon',
#   'Lat': 52.3305,
#   'Lng': -0.1865,
#   'Max Temp': 48.18,
#   'Humidity': 87,
#   'Cloudiness': 43,
#   'Wind Speed': 3,
#   'Country': 'GB',
#   'Date': '2021-10-30 21:12:12',
#   'Description': 'scattered clouds'},
#  {'City': 'Cache Creek',
#   'Lat': 50.8101,
#   'Lng': -121.3246,
#   'Max Temp': 43.92,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 2.35,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:12:12',
#   'Description': 'clear sky'},
#  {'City': 'Tebingtinggi',
#   'Lat': 3.3285,
#   'Lng': 99.1625,
#   'Max Temp': 73.04,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4.23,
#   'Country': 'ID',
#   'Date': '2021-10-30 21:12:13',
#   'Description': 'heavy intensity rain'},
#  {'City': 'Whitehorse',
#   'Lat': 60.7161,
#   'Lng': -135.0538,
#   'Max Temp': 37.09,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 15.99,
#   'Country': 'CA',
#   'Date': '2021-10-30 21:12:13',
#   'Description': 'overcast clouds'},
#  {'City': 'Priyutnoye',
#   'Lat': 46.1011,
#   'Lng': 43.5072,
#   'Max Temp': 43.57,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 7.92,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:12:14',
#   'Description': 'clear sky'},
#  {'City': 'Riacho De Santana',
#   'Lat': -13.6092,
#   'Lng': -42.9389,
#   'Max Temp': 84.96,
#   'Humidity': 36,
#   'Cloudiness': 56,
#   'Wind Speed': 11.21,
#   'Country': 'BR',
#   'Date': '2021-10-30 21:12:15',
#   'Description': 'broken clouds'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 57.04,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2021-10-30 21:12:15',
#   'Description': 'overcast clouds'},
#  {'City': 'Talcahuano',
#   'Lat': -36.7167,
#   'Lng': -73.1167,
#   'Max Temp': 64.08,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'CL',
#   'Date': '2021-10-30 21:12:16',
#   'Description': 'clear sky'},
#  {'City': 'Shuyskoye',
#   'Lat': 59.3736,
#   'Lng': 41.0305,
#   'Max Temp': 41.45,
#   'Humidity': 94,
#   'Cloudiness': 85,
#   'Wind Speed': 4.94,
#   'Country': 'RU',
#   'Date': '2021-10-30 21:12:16',
#   'Description': 'overcast clouds'},
#  {'City': 'Bereda',
#   'Lat': 43.2686,
#   'Lng': -7.5406,
#   'Max Temp': 61,
#   'Humidity': 91,
#   'Cloudiness': 95,
#   'Wind Speed': 5.86,
#   'Country': 'ES',
#   'Date': '2021-10-30 21:12:17',
#   'Description': 'overcast clouds'},
#  {'City': 'Kentau',
#   'Lat': 43.5206,
#   'Lng': 68.5094,
#   'Max Temp': 46.04,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 1.41,
#   'Country': 'KZ',
#   'Date': '2021-10-30 21:12:18',
#   'Description': 'overcast clouds'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 78.1,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 6.29,
#   'Country': 'ID',
#   'Date': '2021-10-30 21:12:18',
#   'Description': 'overcast clouds'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 30.42,
#   'Humidity': 68,
#   'Cloudiness': 92,
#   'Wind Speed': 4.85,
#   'Country': 'GL',
#   'Date': '2021-10-30 21:12:19',
#   'Description': 'overcast clouds'}]

# %%
city_df = pd.DataFrame(city_data)

# %%
city_df
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# 0                     Dikson  73.5069   80.5464      6.93        91
# 1               Punta Arenas -53.1500  -70.9167     53.11        40
# 2                 Hambantota   6.1241   81.1185     78.51        84
# 3                     Ixtapa  20.7000 -105.2000     85.23        81
# 4    San Carlos De Bariloche -41.1456  -71.3082     62.35        14
# ..                       ...      ...       ...       ...       ...
# 686                Shuyskoye  59.3736   41.0305     41.45        94
# 687                   Bereda  43.2686   -7.5406     61.00        91
# 688                   Kentau  43.5206   68.5094     46.04        57
# 689               Banda Aceh   5.5577   95.3222     78.10        83
# 690                   Narsaq  60.9167  -46.0500     30.42        68
#
#      Cloudiness  Wind Speed Country                 Date       Description
# 0           100       16.26      RU  2021-10-30 21:07:25   overcast clouds
# 1            59        7.45      CL  2021-10-30 21:00:37     broken clouds
# 2            79        3.11      LK  2021-10-30 21:07:26     broken clouds
# 3            43        5.99      MX  2021-10-30 21:07:26  scattered clouds
# 4             0       17.27      AR  2021-10-30 21:04:19         clear sky
# ..          ...         ...     ...                  ...               ...
# 686          85        4.94      RU  2021-10-30 21:12:16   overcast clouds
# 687          95        5.86      ES  2021-10-30 21:12:17   overcast clouds
# 688         100        1.41      KZ  2021-10-30 21:12:18   overcast clouds
# 689          98        6.29      ID  2021-10-30 21:12:18   overcast clouds
# 690          92        4.85      GL  2021-10-30 21:12:19   overcast clouds
#
# [691 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_df.to_csv(output_data_file, index_label="City_ID")
